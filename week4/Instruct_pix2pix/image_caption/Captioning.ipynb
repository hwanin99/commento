# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Instruct_pix2pix
# Out:
# /content/drive/MyDrive/experiment_pokemon

# %% [markdown]
# # Generate Caption

# %%
from image_caption.captioning import captioning

# %%
captioning(dir_path = './image2sketch/dataset/images')
