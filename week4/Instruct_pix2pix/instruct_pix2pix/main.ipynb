# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Instruct_pix2pix
# Out:
# /content/drive/MyDrive/experiment_pokemon

# %% [markdown]
# # Create Json

# %%
from instruct_pix2pix.utils.make_metadata import make_metadata

# %%
original_img_dir = './image2sketch/dataset/sketch/*.jpg' #Change to your original image path.
edited_img_dir = './image2sketch/dataset/images/*.jpg' #Change to your edited image path.
desc_path = './image_caption/dataset/modified_desc.csv' #Change to your desc file path.
save_path = './instruct_pix2pix/dataset'

make_metadata(original_img_dir,edited_img_dir,desc_path, save_path)
# Out:
# Dataset creation complete! Total pairs: 819

# %%
with open('./instruct_pix2pix/dataset/metadata.jsonl', 'r') as f:
  json_data = [json.loads(line) for line in f]

# %%
json_data[0]
# Out:
# {'original_image': './image2sketch/dataset/sketch/0.jpg',
#  'edited_image': './image2sketch/dataset/images/0.jpg',
#  'edit_prompt': 'Turn it into a vibrant and cheerful drawing of Bulbasaur, a green Pokémon with red eyes and a green tail, smiling amidst lush greenery, designed as a computer icon with a transparent background.'}

# %% [markdown]
# # Train
# ---
# * colab환경이라, argparse대신에 easydict사용

# %%
from instruct_pix2pix.utils.train import main

# %%
main()

# %% [markdown]
# # Generate Image

# %%
from instruct_pix2pix.utils.inference import generate

# %%
generate(checkpoint_path="./instruct_pix2pix_model/",
           image_path = f'./image2sketch/dataset/sketch/0.jpg',
           prompt = 'Turn it into a creature with a white belly and a red face and back.'
          )
