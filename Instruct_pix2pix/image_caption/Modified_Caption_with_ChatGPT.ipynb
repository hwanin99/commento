# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Instruct_pix2pix
# Out:
# /content/drive/MyDrive/Instruct_pix2pix

# %% [markdown]
# # Edit Caption

# %%
from image_caption.edit_caption import save_modified_captions

# %%
csv_path = './image_caption/dataset/desc.csv'
img_root = './image2sketch/dataset/images'  # 이미지 폴더 경로
output_file = './image_caption/dataset/modified_desc.csv'

save_modified_captions(csv_path, img_root, output_file)
